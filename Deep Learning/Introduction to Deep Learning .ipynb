# %% [markdown]
# # Getting Started with Deep Learning

# %%
import pandas as pd 

red_wine = pd.read_csv('red-wine.csv')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from tensorflow import keras 
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[11])
])

# %%
w, b = model.weights
print("Weights\n{}\n\nBias\n{}".format(w, b))
# Out:
# Weights
# <tf.Variable 'dense/kernel:0' shape=(11, 1) dtype=float32, numpy=
# array([[ 0.67163366],
#        [-0.07246071],
#        [ 0.18755281],
#        [ 0.54325193],
#        [ 0.23139274],
#        [-0.44673535],
#        [-0.4645921 ],
#        [ 0.2024647 ],
#        [-0.57671356],
#        [ 0.19450974],
#        [-0.30144572]], dtype=float32)>
#
# Bias
# <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

model = keras.Sequential([
    layers.Dense(1, input_shape=[1]),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w, b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=4, activation='relu', input_shape=[2]),
    layers.Dense(units=3, activation='relu'),
    # the linear output layer 
    layers.Dense(units=1),
])

# %%
import pandas as pd 

concrete = pd.read_csv('concrete.csv')
concrete.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[8]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),    
    layers.Dense(1),
])

# %%
### YOUR CODE HERE: rewrite this to use activation layers
model = keras.Sequential([
    layers.Dense(32, input_shape=[8]),
    layers.Activation('relu'),
    layers.Dense(32),
    layers.Activation('relu'),
    layers.Dense(1),
])

# %%
import pandas as pd
from IPython.display import display

red_wine = pd.read_csv('red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[11]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=10,
)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 1s 51ms/step - loss: 0.2525 - val_loss: 0.1364
# Epoch 2/10
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1419 - val_loss: 0.1226
# Epoch 3/10
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1230 - val_loss: 0.1169
# Epoch 4/10
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1165 - val_loss: 0.1083
# Epoch 5/10
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1092 - val_loss: 0.1121
# Epoch 6/10
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1065 - val_loss: 0.1030
# Epoch 7/10
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1061 - val_loss: 0.1022
# Epoch 8/10
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1028 - val_loss: 0.1038
# Epoch 9/10
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1019 - val_loss: 0.1012
# Epoch 10/10
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1025 - val_loss: 0.0991

# %%
import pandas as pd

# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot();

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

fuel = pd.read_csv('fuel.csv')


X = fuel.copy()
# Remove target
y = X.pop('FE')

preprocessor = make_column_transformer(
    (StandardScaler(),
     make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse=False),
     make_column_selector(dtype_include=object)),
)

X = preprocessor.fit_transform(X)
y = np.log(y) # log transform target instead of standardizing

input_shape = [X.shape[1]]
print("Input shape: {}".format(input_shape))
fuel.head()
# Out:
# Input shape: [50]
#    EngDispl  NumCyl Transmission       FE AirAspirationMethod  NumGears  \
# 0       4.7       8          AM6  28.0198  NaturallyAspirated         6
# 1       4.7       8           M6  25.6094  NaturallyAspirated         6
# 2       4.2       8           M6  26.8000  NaturallyAspirated         6
# 3       4.2       8          AM6  25.0451  NaturallyAspirated         6
# 4       5.2      10          AM6  24.8000  NaturallyAspirated         6
#
#    TransLockup  TransCreeperGear          DriveDesc  IntakeValvePerCyl  \
# 0            1                 0  TwoWheelDriveRear                  2
# 1            1                 0  TwoWheelDriveRear                  2
# 2            1                 0      AllWheelDrive                  2
# 3            1                 0      AllWheelDrive                  2
# 4            0                 0      AllWheelDrive                  2
#
#    ExhaustValvesPerCyl CarlineClassDesc  VarValveTiming  VarValveLift
# 0                    2         2Seaters               1             0
# 1                    2         2Seaters               1             0
# 2                    2         2Seaters               1             0
# 3                    2         2Seaters               1             0
# 4                    2         2Seaters               1             0

# %%
from tensorflow import keras 
from tensorflow.keras import layers 

model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape), 
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer = 'adam',
    loss = 'mae',
)

# %%
import pandas as pd

history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5. You can change this to get a different view.
history_df.loc[5:, ['loss']].plot();

# %%
"""
learning_rate	batch_size	num_examples
0.05	32	256
0.05	2	256
0.05	128	256
0.02	32	256
0.2	32	256
1.0	32	256
0.9	4096	8192
0.99	4096	8192
"""
# Out:
# '\nlearning_rate\tbatch_size\tnum_examples\n0.05\t32\t256\n0.05\t2\t256\n0.05\t128\t256\n0.02\t32\t256\n0.2\t32\t256\n1.0\t32\t256\n0.9\t4096\t8192\n0.99\t4096\t8192\n'

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta = 0.001, 
    patience = 20, 
    restore_best_weights = True, 
)

# %%
import pandas as pd
from IPython.display import display

red_wine = pd.read_csv('red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
from tensorflow import keras 
from tensorflow.keras import layers, callbacks 

early_stopping = callbacks.EarlyStopping(
    min_delta = 0.001, 
    patience = 20,
    restore_best_weights = True,
)

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape = [11]), 
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer = "adam",
    loss = "mae", 
)

# %%
history = model.fit(
    X_train, y_train, 
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping], # Put your callbacks in a list 
    verbose=0, # Turn off training log 
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.09134847670793533

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]

print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 4ms/step - loss: 0.2534 - val_loss: 0.2146
# Epoch 2/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.2032 - val_loss: 0.2076
# Epoch 3/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1964 - val_loss: 0.2045
# Epoch 4/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.2034
# Epoch 5/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1908 - val_loss: 0.2018
# Epoch 6/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1888 - val_loss: 0.2026
# Epoch 7/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1870 - val_loss: 0.2021
# Epoch 8/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1862 - val_loss: 0.2013
# Epoch 9/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1852 - val_loss: 0.2019
# Epoch 10/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1840 - val_loss: 0.2004
# Epoch 11/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1832 - val_loss: 0.2013
# Epoch 12/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1824 - val_loss: 0.2020
# Epoch 13/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1818 - val_loss: 0.2010
# Epoch 14/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1810 - val_loss: 0.2013
# Epoch 15/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1807 - val_loss: 0.2036
# Epoch 16/50
# 48/48 [==============================] - 0s 7ms/step - loss: 0.1797 - val_loss: 0.2019
# Epoch 17/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1795 - val_loss: 0.2013
# Epoch 18/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1784 - val_loss: 0.2013
# Epoch 19/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1780 - val_loss: 0.2014
# Epoch 20/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1774 - val_loss: 0.2036
# Epoch 21/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1768 - val_loss: 0.2014
# Epoch 22/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1761 - val_loss: 0.2019
# Epoch 23/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1750 - val_loss: 0.2020
# Epoch 24/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1748 - val_loss: 0.2024
# Epoch 25/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1742 - val_loss: 0.2023
# Epoch 26/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1746 - val_loss: 0.2039
# Epoch 27/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1734 - val_loss: 0.2027
# Epoch 28/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1732 - val_loss: 0.2022
# Epoch 29/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1726 - val_loss: 0.2039
# Epoch 30/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1717 - val_loss: 0.2036
# Epoch 31/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1714 - val_loss: 0.2021
# Epoch 32/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1713 - val_loss: 0.2037
# Epoch 33/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1709 - val_loss: 0.2043
# Epoch 34/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1699 - val_loss: 0.2049
# Epoch 35/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1694 - val_loss: 0.2050
# Epoch 36/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1712 - val_loss: 0.2055
# Epoch 37/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1693 - val_loss: 0.2051
# Epoch 38/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1694 - val_loss: 0.2047
# Epoch 39/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1677 - val_loss: 0.2047
# Epoch 40/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1677 - val_loss: 0.2054
# Epoch 41/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1676 - val_loss: 0.2067
# Epoch 42/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1673 - val_loss: 0.2074
# Epoch 43/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1666 - val_loss: 0.2064
# Epoch 44/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1656 - val_loss: 0.2065
# Epoch 45/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1656 - val_loss: 0.2068
# Epoch 46/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1656 - val_loss: 0.2067
# Epoch 47/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1643 - val_loss: 0.2063
# Epoch 48/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1645 - val_loss: 0.2064
# Epoch 49/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1636 - val_loss: 0.2076
# Epoch 50/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1638 - val_loss: 0.2065
# Minimum Validation Loss: 0.2004

# %%
from tensorflow.keras import callbacks

# YOUR CODE HERE: define an early stopping callback
early_stopping = callbacks.EarlyStopping(
    patience = 5, 
    min_delta = 0.001, 
    restore_best_weights = True,
)

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(rate=0.3),
    layers.Dense(64, activation='relu'),    
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    callbacks=[early_stopping]
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 5ms/step - loss: 0.2459 - val_loss: 0.2099
# Epoch 2/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.2127 - val_loss: 0.2082
# Epoch 3/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2057 - val_loss: 0.2040
# Epoch 4/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.2018 - val_loss: 0.2054
# Epoch 5/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2000 - val_loss: 0.2014
# Epoch 6/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1984 - val_loss: 0.2008
# Epoch 7/50
# 48/48 [==============================] - 0s 7ms/step - loss: 0.1965 - val_loss: 0.2009
# Epoch 8/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1960 - val_loss: 0.1989
# Epoch 9/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1943 - val_loss: 0.2003
# Epoch 10/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1936 - val_loss: 0.1980
# Epoch 11/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1928 - val_loss: 0.2009
# Epoch 12/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1926 - val_loss: 0.1995
# Epoch 13/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1924 - val_loss: 0.1980
# Minimum Validation Loss: 0.1980

# %% [markdown]
# ## Dropout and Batch Normalization

# %%
# Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)


import pandas as pd
red_wine = pd.read_csv('red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(1024, activation='relu', input_shape=[11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=100,
    verbose=0,
)


# Show the learning curves
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();

# %% [markdown]
# #### Dropout

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(rate=0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(rate=0.3),
    layers.Dense(1)
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 0.1973

# %% [markdown]
# #### Batch Normalization

# %%
import pandas as pd

concrete = pd.read_csv('concrete.csv')
df = concrete.copy()

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

X_train = df_train.drop('CompressiveStrength', axis=1)
X_valid = df_valid.drop('CompressiveStrength', axis=1)
y_train = df_train['CompressiveStrength']
y_valid = df_valid['CompressiveStrength']

input_shape = [X_train.shape[1]]

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.Dense(512, activation='relu'),    
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
model.compile(
    optimizer='sgd', # SGD is more sensitive to differences of scale
    loss='mae',
    metrics=['mae'],
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100,
    verbose=0,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: nan

# %%
# YOUR CODE HERE: Add a BatchNormalization layer before each Dense layer
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae'],
)
EPOCHS = 100
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=EPOCHS,
    verbose=0,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 3.6228

# %% [markdown]
# ## Training Neural Networks for Binary Classification

# %%
import pandas as pd
from IPython.display import display

ion = pd.read_csv('ion.csv', index_col=0)
display(ion.head())

df = ion.copy()
df['Class'] = df['Class'].map({'good': 0, 'bad': 1})

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)

df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)
df_train.dropna(axis=1, inplace=True) # drop the empty feature in column 2
df_valid.dropna(axis=1, inplace=True)

X_train = df_train.drop('Class', axis=1)
X_valid = df_valid.drop('Class', axis=1)
y_train = df_train['Class']
y_valid = df_valid['Class']
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 1  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 2 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 3  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 4  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 5 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 1 -0.54487  0.18641 -0.45300   good
# 2 -0.06288 -0.13738 -0.02447    bad
# 3 -0.24180  0.56045 -0.38238   good
# 4  1.00000 -0.32382  1.00000    bad
# 5 -0.59573 -0.04608 -0.65697   good
#
# [5 rows x 35 columns]

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[33]),
    layers.Dense(4, activation='relu'),    
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer = "adam",
    loss = "binary_crossentropy",
    metrics = ['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train, 
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=0,
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.4170
# Best Validation Accuracy: 0.8571

# %% [markdown]
# ### Build a Model to Predict Hotel Cancellations with a binary classifier

# %% [markdown]
# #### Load the Hotel Cancellations dataset

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
X.head()
# Out:
#           hotel  lead_time  arrival_date_year  arrival_date_month  \
# 0  Resort Hotel        342               2015                   7
# 1  Resort Hotel        737               2015                   7
# 2  Resort Hotel          7               2015                   7
# 3  Resort Hotel         13               2015                   7
# 4  Resort Hotel         14               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                        0                     0       2       0.0  ...
# 1                        0                     0       2       0.0  ...
# 2                        0                     1       1       0.0  ...
# 3                        0                     1       1       0.0  ...
# 4                        0                     2       2       0.0  ...
#
#    deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 0    No Deposit    NaN     NaN                    0     Transient   0.0
# 1    No Deposit    NaN     NaN                    0     Transient   0.0
# 2    No Deposit    NaN     NaN                    0     Transient  75.0
# 3    No Deposit  304.0     NaN                    0     Transient  75.0
# 4    No Deposit  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                            0                          0          Check-Out
# 1                            0                          0          Check-Out
# 2                            0                          0          Check-Out
# 3                            0                          0          Check-Out
# 4                            0                          1          Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Define Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers 

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape), 
    layers.Dense(256, activation='relu'), 
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# #### Compile the model with the Adam Optimizer and binary versions of the cross-entropy and accuracy metric

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["binary_accuracy"],
)

# %% [markdown]
# #### Train the model and view the learning curves

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 3s 11ms/step - loss: 0.4817 - binary_accuracy: 0.7711 - val_loss: 0.4433 - val_binary_accuracy: 0.8052
# Epoch 2/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.4218 - binary_accuracy: 0.8017 - val_loss: 0.4037 - val_binary_accuracy: 0.8110
# Epoch 3/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.4103 - binary_accuracy: 0.8070 - val_loss: 0.3978 - val_binary_accuracy: 0.8158
# Epoch 4/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4017 - binary_accuracy: 0.8115 - val_loss: 0.3933 - val_binary_accuracy: 0.8186
# Epoch 5/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3969 - binary_accuracy: 0.8152 - val_loss: 0.3898 - val_binary_accuracy: 0.8190
# Epoch 6/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3918 - binary_accuracy: 0.8169 - val_loss: 0.3875 - val_binary_accuracy: 0.8216
# Epoch 7/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3876 - binary_accuracy: 0.8199 - val_loss: 0.3855 - val_binary_accuracy: 0.8232
# Epoch 8/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3855 - binary_accuracy: 0.8213 - val_loss: 0.3786 - val_binary_accuracy: 0.8255
# Epoch 9/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3820 - binary_accuracy: 0.8225 - val_loss: 0.3777 - val_binary_accuracy: 0.8276
# Epoch 10/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3787 - binary_accuracy: 0.8248 - val_loss: 0.3751 - val_binary_accuracy: 0.8287
# Epoch 11/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3740 - binary_accuracy: 0.8264 - val_loss: 0.3745 - val_binary_accuracy: 0.8278
# Epoch 12/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3721 - binary_accuracy: 0.8269 - val_loss: 0.3706 - val_binary_accuracy: 0.8304
# Epoch 13/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3705 - binary_accuracy: 0.8278 - val_loss: 0.3756 - val_binary_accuracy: 0.8264
# Epoch 14/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3674 - binary_accuracy: 0.8308 - val_loss: 0.3684 - val_binary_accuracy: 0.8309
# Epoch 15/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3665 - binary_accuracy: 0.8313 - val_loss: 0.3641 - val_binary_accuracy: 0.8324
# Epoch 16/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3652 - binary_accuracy: 0.8304 - val_loss: 0.3663 - val_binary_accuracy: 0.8311
# Epoch 17/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3631 - binary_accuracy: 0.8325 - val_loss: 0.3661 - val_binary_accuracy: 0.8324
# Epoch 18/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3619 - binary_accuracy: 0.8338 - val_loss: 0.3637 - val_binary_accuracy: 0.8337
# Epoch 19/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3597 - binary_accuracy: 0.8337 - val_loss: 0.3656 - val_binary_accuracy: 0.8315
# Epoch 20/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3571 - binary_accuracy: 0.8348 - val_loss: 0.3594 - val_binary_accuracy: 0.8347
# Epoch 21/200
# 175/175 [==============================] - 3s 14ms/step - loss: 0.3578 - binary_accuracy: 0.8352 - val_loss: 0.3618 - val_binary_accuracy: 0.8345
# Epoch 22/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3562 - binary_accuracy: 0.8363 - val_loss: 0.3573 - val_binary_accuracy: 0.8364
# Epoch 23/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3538 - binary_accuracy: 0.8364 - val_loss: 0.3662 - val_binary_accuracy: 0.8311
# Epoch 24/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3536 - binary_accuracy: 0.8377 - val_loss: 0.3579 - val_binary_accuracy: 0.8355
# Epoch 25/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3524 - binary_accuracy: 0.8380 - val_loss: 0.3580 - val_binary_accuracy: 0.8356
# Epoch 26/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3514 - binary_accuracy: 0.8391 - val_loss: 0.3569 - val_binary_accuracy: 0.8360
# Epoch 27/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3504 - binary_accuracy: 0.8381 - val_loss: 0.3560 - val_binary_accuracy: 0.8362
# Epoch 28/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3481 - binary_accuracy: 0.8393 - val_loss: 0.3584 - val_binary_accuracy: 0.8341
# Epoch 29/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3470 - binary_accuracy: 0.8406 - val_loss: 0.3601 - val_binary_accuracy: 0.8351
# Epoch 30/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3472 - binary_accuracy: 0.8397 - val_loss: 0.3606 - val_binary_accuracy: 0.8352
# Epoch 31/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3448 - binary_accuracy: 0.8413 - val_loss: 0.3553 - val_binary_accuracy: 0.8385
# Epoch 32/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3454 - binary_accuracy: 0.8411 - val_loss: 0.3534 - val_binary_accuracy: 0.8381
# Epoch 33/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3450 - binary_accuracy: 0.8414 - val_loss: 0.3528 - val_binary_accuracy: 0.8383
# Epoch 34/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3431 - binary_accuracy: 0.8430 - val_loss: 0.3551 - val_binary_accuracy: 0.8367
# Epoch 35/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3411 - binary_accuracy: 0.8436 - val_loss: 0.3523 - val_binary_accuracy: 0.8380
# Epoch 36/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3415 - binary_accuracy: 0.8430 - val_loss: 0.3530 - val_binary_accuracy: 0.8391
# Epoch 37/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3407 - binary_accuracy: 0.8432 - val_loss: 0.3564 - val_binary_accuracy: 0.8376
# Epoch 38/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3399 - binary_accuracy: 0.8433 - val_loss: 0.3562 - val_binary_accuracy: 0.8367
# Epoch 39/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3378 - binary_accuracy: 0.8441 - val_loss: 0.3573 - val_binary_accuracy: 0.8368
# Epoch 40/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3381 - binary_accuracy: 0.8439 - val_loss: 0.3532 - val_binary_accuracy: 0.8399

# %%
# Though we can see the training loss continuing to fall, 
# the early stopping callback prevented any overfitting. 
# Moreover, the accuracy rose at the same rate as the cross-entropy fell, 
# so it appears that minimizing cross-entropy was a good stand-in. 
# All in all, it looks like this training was a success!
